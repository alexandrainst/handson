# %%
"""
Before running this code, make sure you have downloaded the dataset needed. Run /data/download_cats_and_dogs.py to get the dataset.

All the notebook examples should run the same code, but will highlight different aspects of it.

In this first example, the goal is to get a high overview of the code.
"""

# %%
from config.efficient_net_b2_pretrained import Configuration

# load configuration information
configuration = Configuration()
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 3.5 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 23.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.0/306.0 kB 22.1 MB/s eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 37.2 MB/s eta 0:00:00a 0:00:01
# Using cached kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 23.1 MB/s eta 0:00:00
# ...

# %%
import torch

from src.dataloader import load_data_wrapper
from src.losses import select_loss_fnc
from src.model import model_loader_wrapper
from src.optimizer import optimize_model
from src.viz import eval_unlabelled_images, plot_loss_and_accuracy
# Out:
# dogs-vs-cats/train/cat.12209.jpg
# dogs-vs-cats/train/dog.4793.jpg

# %%
dataloaders = load_data_wrapper(**configuration)
model = model_loader_wrapper(**configuration)
optimizer = torch.optim.Adam(model.parameters(), lr=configuration['lr'])
loss_fnc = select_loss_fnc(**configuration)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x374>

# %%
losses, accuracies = optimize_model(model, dataloaders, optimizer, loss_fnc, **configuration)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=384x441>

# %%
plot_loss_and_accuracy(losses, accuracies)

# %% [markdown]
# # Questions to consider
#
# 1. The optimize_model step gives both a loss and an accuracy, what do you think these are? How do they differ?
# 2. There are 4 components (+configuration) that goes into the optimize_model, based on what you have seen so far, can you already imagine how they might work together?
